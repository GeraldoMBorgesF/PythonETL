# %%
import pandas as pd

# %%
df = pd.read_csv("ocorrencia.csv", sep=";", parse_dates=['ocorrencia_dia'],dayfirst=True)
df.head()
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 0              52242               52242               52242
# 1              45331               45331               45331
# 2              45333               45333               45333
# 3              45401               45401               45401
# 4              45407               45407               45407
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 0               52242               52242                INCIDENTE
# 1               45331               45331                 ACIDENTE
# 2               45333               45333                 ACIDENTE
# 3               45401               45401                 ACIDENTE
# 4               45407               45407                 ACIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 0                 NaN                  NaN      PORTO ALEGRE            RS
# ...

# %%
df.loc[1,"ocorrencia_cidade"]
#Consulta de um dado específico na interseção linha X coluna
# Out:
# 'GUARULHOS'

# %%
df.loc[1:3]
#Consulta de um intervalo de linhas
# Out:
#    codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 1              45331               45331               45331
# 2              45333               45333               45333
# 3              45401               45401               45401
#
#    codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 1               45331               45331                 ACIDENTE
# 2               45333               45333                 ACIDENTE
# 3               45401               45401                 ACIDENTE
#
#   ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 1      -23.4355555556       -46.4730555556         GUARULHOS            SP
# 2                 ***                  ***            VIAMÃO            RS
# 3                 ***                  ***     SÃO SEBASTIÃO            SP
#
#    ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# 1  ...     2012-01-06        13:44:00                            SIM
# ...

# %%
df.loc[[10,21,40]]
#Consulta linhas específicas, neste caso as linhas 10,21 e 40
# Out:
#     codigo_ocorrencia  codigo_ocorrencia1  codigo_ocorrencia2  \
# 10              45332               45332               45332
# 21              45392               45392               45392
# 40              45415               45415               45415
#
#     codigo_ocorrencia3  codigo_ocorrencia4 ocorrencia_classificacao  \
# 10               45332               45332                 ACIDENTE
# 21               45392               45392                 ACIDENTE
# 40               45415               45415                 ACIDENTE
#
#    ocorrencia_latitude ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 10                 ***                  ***            VIAMÃO            RS
# 21      -15.8197222222       -47.8747222222          BRASÍLIA            DF
# 40                 ***                  ***    RIO DE JANEIRO            RJ
#
#     ... ocorrencia_dia ocorrencia_hora investigacao_aeronave_liberada  \
# ...

# %%
df.loc[:,'ocorrencia_aerodromo']
#Consulta de uma coluna inteira
# Out:
# 0        SBPA
# 1        SBGR
# 2        ****
# 3        ****
# 4        ****
#         ...
# 5162     ####
# 5163    *****
# 5164     SSNH
# 5165     SBBI
# 5166     SBPL
# Name: ocorrencia_aerodromo, Length: 5167, dtype: object

# %%
df.codigo_ocorrencia.is_unique
#Verifica se cada dado da coluna citada é único, ou seja, se cada dado daquela coluna é diferente do outro
# Out:
# True

# %%
df.set_index('codigo_ocorrencia', inplace=True)
#Transforma a coluna especificada em índice e o comando (inplace=True) altera o arquivo

# %%
df.head()
# Out:
#                    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# codigo_ocorrencia
# 52242                           52242               52242               52242
# 45331                           45331               45331               45331
# 45333                           45333               45333               45333
# 45401                           45401               45401               45401
# 45407                           45407               45407               45407
#
#                    codigo_ocorrencia4 ocorrencia_classificacao  \
# codigo_ocorrencia
# 52242                           52242                INCIDENTE
# 45331                           45331                 ACIDENTE
# 45333                           45333                 ACIDENTE
# 45401                           45401                 ACIDENTE
# 45407                           45407                 ACIDENTE
#
# ...

# %%
df.loc[45407]
# Out:
# codigo_ocorrencia1                              45407
# codigo_ocorrencia2                              45407
# codigo_ocorrencia3                              45407
# codigo_ocorrencia4                              45407
# ocorrencia_classificacao                     ACIDENTE
# ocorrencia_latitude                               ***
# ocorrencia_longitude                              ***
# ocorrencia_cidade                            SÃO SEPÉ
# ocorrencia_uf                                      RS
# ocorrencia_pais                                BRASIL
# ocorrencia_aerodromo                             ****
# ocorrencia_dia                    2012-01-06 00:00:00
# ocorrencia_hora                              16:30:00
# investigacao_aeronave_liberada                    SIM
# investigacao_status                        FINALIZADA
# divulgacao_relatorio_numero         A-071/CENIPA/2013
# divulgacao_relatorio_publicado                    SIM
# ...

# %%
df.reset_index(drop=True,inplace=True)
#Reseta o índice

# %%
df.head()
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               52242               52242               52242
# 1               45331               45331               45331
# 2               45333               45333               45333
# 3               45401               45401               45401
# 4               45407               45407               45407
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               52242                INCIDENTE                 NaN
# 1               45331                 ACIDENTE      -23.4355555556
# 2               45333                 ACIDENTE                 ***
# 3               45401                 ACIDENTE                 ***
# 4               45407                 ACIDENTE                 ***
#
#   ocorrencia_longitude ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  NaN      PORTO ALEGRE            RS          BRASIL  ...
# ...

# %%
df.loc[df.ocorrencia_uf == 'SP',['ocorrencia_classificacao']]='GRAVE'
#Altera os dados de uma coluna em referencia a outra coluna, neste caso, onde tem o dado 'SP' 
#na coluna UF, será alterado o dado para "Grave", na coluna classificação

# %%
df.head()
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               52242               52242               52242
# 1               45331               45331               45331
# 2               45333               45333               45333
# 3               45401               45401               45401
# 4               45407               45407               45407
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               52242                INCIDENTE                 NaN
# 1               45331                    GRAVE      -23.4355555556
# 2               45333                 ACIDENTE                 ***
# 3               45401                    GRAVE                 ***
# 4               45407                 ACIDENTE                 ***
#
#   ocorrencia_longitude ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0                  NaN      PORTO ALEGRE            RS          BRASIL  ...
# ...

# %%
df.loc[df.ocorrencia_uf =='SP']
# Out:
#       codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 1                  45331               45331               45331
# 3                  45401               45401               45401
# 5                  52243               52243               52243
# 6                  50713               50713               50713
# 13                 45408               45408               45408
# ...                  ...                 ...                 ...
# 5148               80441               80441               80441
# 5157               80453               80453               80453
# 5158               80454               80454               80454
# 5161               80456               80456               80456
# 5163               80452               80452               80452
#
#       codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 1                  45331                    GRAVE      -23.4355555556
# ...

# %% [raw]
# ocorrencia_uf
# **
#
# ocorrencia_aerodromo
# ****
# *****
# ####
# ###!
#
# ocorrencia_hora
# NULL

# %%
df.loc[df.ocorrencia_aerodromo=='****',['ocorrencia_aerodromo']]=pd.NA
df.loc[df.ocorrencia_aerodromo=='####',['ocorrencia_aerodromo']]=pd.NA
df.loc[df.ocorrencia_aerodromo=='*****',['ocorrencia_aerodromo']]=pd.NA

#O comando abaixo limpa todo o dataframe
df.replace(['**','***','###!','####','*****','NULL'], pd.NA, inplace=True)

# %%
df.loc[:,'ocorrencia_aerodromo']

# %%
df.isna().sum()
#Verifica a quantidade de dados tipo 'NA ou null' existem na tabela
# Out:
# codigo_ocorrencia1                0
# codigo_ocorrencia2                0
# codigo_ocorrencia3                0
# codigo_ocorrencia4                0
# ocorrencia_classificacao          0
# ocorrencia_latitude               0
# ocorrencia_longitude              0
# ocorrencia_cidade                 0
# ocorrencia_uf                     0
# ocorrencia_pais                   0
# ocorrencia_aerodromo              0
# ocorrencia_dia                    0
# ocorrencia_hora                   0
# investigacao_aeronave_liberada    0
# investigacao_status               0
# divulgacao_relatorio_numero       0
# divulgacao_relatorio_publicado    0
# divulgacao_dia_publicacao         0
# total_recomendacoes               0
# total_aeronaves_envolvidas        0
# ocorrencia_saida_pista            0
# dtype: int64

# %%
df.fillna("não informado",inplace = True)
#substitui os dados "na" pelo dado entre parênteses

# %%
df.head()
# Out:
#    codigo_ocorrencia1  codigo_ocorrencia2  codigo_ocorrencia3  \
# 0               52242               52242               52242
# 1               45331               45331               45331
# 2               45333               45333               45333
# 3               45401               45401               45401
# 4               45407               45407               45407
#
#    codigo_ocorrencia4 ocorrencia_classificacao ocorrencia_latitude  \
# 0               52242                INCIDENTE       não informado
# 1               45331                    GRAVE      -23.4355555556
# 2               45333                 ACIDENTE       não informado
# 3               45401                    GRAVE       não informado
# 4               45407                 ACIDENTE       não informado
#
#   ocorrencia_longitude ocorrencia_cidade ocorrencia_uf ocorrencia_pais  ...  \
# 0        não informado      PORTO ALEGRE            RS          BRASIL  ...
# ...

# %%
#Exclui as colunas
df.drop(['codigo_ocorrencia2','codigo_ocorrencia3','codigo_ocorrencia4','ocorrencia_pais','investigacao_aeronave_liberada'],axis=1,inplace=True)

# %%
df.drop_duplicates()
#exclui as linhas duplicadas
# Out:
#       codigo_ocorrencia1 ocorrencia_classificacao ocorrencia_latitude  \
# 0                  52242                INCIDENTE       não informado
# 1                  45331                    GRAVE      -23.4355555556
# 2                  45333                 ACIDENTE       não informado
# 3                  45401                    GRAVE       não informado
# 4                  45407                 ACIDENTE       não informado
# ...                  ...                      ...                 ...
# 5162               80458                 ACIDENTE          -17.999194
# 5163               80452                    GRAVE          -22.585556
# 5164               80457          INCIDENTE GRAVE          -29.695833
# 5165               80460                INCIDENTE          -25.403333
# 5166               80467                INCIDENTE             -9.3675
#
#      ocorrencia_longitude ocorrencia_cidade ocorrencia_uf  \
# 0           não informado      PORTO ALEGRE            RS
# ...
